# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
import warnings
warnings.filterwarnings("ignore")

# %%
X,y=make_blobs(n_samples=2500,centers=4,n_features=2,random_state=0)
Y_pred=KMeans(n_clusters=4,random_state=0).fit_predict(X)

# %%
plt.figure(1)
plt.scatter(X[:,0],X[:,1],c=Y_pred,cmap="jet")
plt.suptitle("K-Means Clusters")
plt.grid(1,which="both")
plt.axis("tight")
plt.show()

# %%
plt.figure(2)
plt.scatter(X[:,0],X[:,1],c=y,cmap="jet")
plt.suptitle("Clusters_make_blob")
plt.grid(1,which="both")
plt.axis("tight")
plt.show()

# %%
cmat=confusion_matrix(Y_pred,y)
ConfusionMatrixDisplay(cmat,display_labels=None).plot()

# %%
 X, y = make_blobs(n_samples=10, centers=3, n_features=2, random_state=2)

# %%
# The integer labels for cluster membership of each sample.
y
# Out:
# array([0, 0, 1, 0, 2, 2, 2, 1, 1, 0])

# %%
plt.scatter(X[:,0],X[:,1],c=y,cmap="jet")
